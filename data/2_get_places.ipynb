# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
df
# Out:
#      Unnamed: 0           publishedAt  \
# 0             0  2024-01-01T16:00:06Z
# 1             1  2023-12-25T16:00:08Z
# 2             2  2023-12-18T16:00:18Z
# 3             3  2023-12-11T16:00:31Z
# 4             4  2023-12-04T16:00:40Z
# ..          ...                   ...
# 726         726  2007-09-03T10:45:33Z
# 727         727  2007-04-08T13:54:51Z
# 728         728  2006-07-05T12:12:09Z
# 729         729  2006-07-04T12:41:29Z
# 730         730  2006-06-06T22:22:19Z
#
#                                                  title  \
# 0    After ten years, it's time to stop weekly videos.
# 1           People are going to be angry about pylons.
# 2         Why the government drops flies on California
# 3       A robot just swapped my electric car's battery
# 4                   Why don't subtitles match dubbing?
# ..                                                 ...
# 726  On A Pirate Ship - Jay Foreman feat. Mad Cap'n...
# 727                         Fun With A Giant Slingshot
# 728            Pastaaargh: pasta, cooked with a kettle
# 729                               Extra Light Pancakes
# 730                     Breakfast: Fortified With Iron
#
#                                            description      videoId
# 0    Find me here: ❓ LATERAL, free weekly podcast: ...  7DKv5H5Frt0
# 1    Britain's power grid is turning inside-out, wh...  F0JDK_71yDg
# 2    There's a good reason for it. ■ More about the...  Zl_5LT2fzak
# 3    Nio is a Chinese auto maker that offers an alt...  hNZy603as5w
# 4    Translation is really difficult. ■ AD: 👨‍💻 Nor...  pU9sHwNKc2c
# ..                                                 ...          ...
# 726  www.yarr.org.uk/single - (remixes too!) \r\n\r...  dK-pMy_jOKI
# 727  http://www.tomscott.com - One old monitor. One...  dNOWXi8KoOs
# 728  http://www.tomscott.com - Penne pasta and mari...  sZ363XfT8fk
# 729  http://www.tomscott.com - Pancakes, cooked usi...  nkTyWTC9UZc
# 730  http://www.tomscott.com - The Iron Chefs: Cook...  MrppkAIVhH4
#
# [731 rows x 5 columns]

# %%
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
client = OpenAI()

# %%
def get_location(row):
    completion = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": "given a video description and title, give the location that the video was filmed.\
              If it's not extremely clear, say \"no location found\" all lowercase with no punctuation. \
             get as specific of a location as possible with the given inputs. \
                Especially if there is a bulilding named in the description, this should be the response.\
             Ideally, output should be formatted 'location, city, state, country' if applicable. If not applicable, just skip"},
            {
                "role": "user",
                "content": f'title: "{row["title"]}", description:"{row["description"]}"'
            }
        ]
    )

    return completion.choices[0].message.content

responses = df.apply(get_location, axis=1)

# %%
df["location"] = responses

# %%
df.to_csv("./data_with_loc.csv")
